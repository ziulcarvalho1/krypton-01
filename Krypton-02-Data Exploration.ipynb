# %%
## Environment and loading the data
import nltk
import numpy as np
import random
import string

import bs4 as bs
import urllib.request
import re

import pandas, numpy
import pandas as pd 
import numpy as np
from datetime import datetime
import seaborn as sns

# %%
df7  = pd.read_csv('C:/AI/Krypton-01/csv-doc/revisado6.csv')

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4448 entries, 0 to 4447
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4448 non-null   object
#  1   label   4443 non-null   object
# dtypes: object(2)
# memory usage: 69.6+ KB

# %%
df7 = df7[df7['label'].notna()]

# %%
df7['label'].value_counts()[:50]
# Out:
# NOTA      4096
# RECIBO     140
# RPA         63
# DOC         61
# BOLETO      42
# OUTROS      41
# Name: label, dtype: int64

# %%
#histogram measurement parameter1 (section 2 - answer 1)
import matplotlib.pyplot as plt
plt.hist(df7.label, bins=3)
# Out:
# (array([4236.,  124.,   83.]),
#  array([0.        , 1.66666667, 3.33333333, 5.        ]),
#  <a list of 3 Patch objects>)

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Invoice', 'Recibo','RPA','DOC','BOLETO','Others'
sizes = [92.19,3.15,1.42,1.37,0.95,0.92]
explode = (0.1, 0,0,0,0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(20, 10))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
