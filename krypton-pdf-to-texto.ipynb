# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
##from io import BytesIO
import codecs

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    #retstr = BytesIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
from os import listdir
from os.path import isfile, join
mypath="C:/AI/Krypton-01/pdfs"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
import re
for file in onlyfiles:
    final = (file[len(file)-3:])
    nome  = (file[:len(file)-4])
    if final=='pdf':
        print(nome)
        arquivo = convert_pdf_to_txt(mypath+"/"+file)
        my_file = open("C:/AI/krypton-01/texto/"+nome+".txt","w+")
        text_file = open("C:/AI/krypton-01/texto/"+nome+".txt", "w")
        cleanString = re.sub('\W+','', arquivo )
        text_file.write(cleanString)
        text_file.close()
# Out:
# 2018-01-03_16-26_3687490
# 2018-01-03_16-26_4703491
# 2018-01-03_16-26_5524444
# 2018-01-03_16-26_6231938
# 2018-01-03_16-27_5976388
# 2018-02-28_17-18_9989703
# 2018-03-01_10-17_3132133
# 2018-03-02_10-01_2736574
# 2018-03-28_14-31_8622216
# 2018-03-28_14-38_7547926
# 2018-04-03_09-31_2771237
# 2018-04-04_12-55_8373498
# 2018-04-04_13-06_1440297
# 2018-04-20_17-01_9523594
# 2018-04-30_15-35_2921528
# 2018-04-30_17-01_1797878
# 2018-06-07_11-05_9763679
# 2018-06-07_13-40_4636502
# 2018-06-08_08-38_7070374
# 2018-06-19_15-24_7898558
# 2018-07-02_15-30_7991822
# 2018-07-11_17-31_3900563
# 2018-07-11_17-31_4230133
# 2018-07-16_11-25_7904157
# 2018-07-17_16-34_3053226
# 2018-08-09_13-26_7969628
# 2018-08-23_12-19_8864061
# 2018-08-23_17-24_4325695
# 2018-08-27_16-48_E_1314_2994433
# 2018-09-03_16-27_8705581
# 2018-09-21_14-46_2421773
# 2018-09-25_10-45_E_1314_4140401
# 2018-09-25_10-47_E_1314_4577560
# 2018-09-25_10-49_E_1314_4544854
# 2018-09-25_10-54_E_1314_5000212
# ...

# %%
# Lendo os arquivos texto
from os import listdir
from os.path import isfile, join
mypath="C:/AI/Krypton-01/texto"
onlyfiles1 = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
for file1 in onlyfiles1:
    final1 = (file1[len(file1)-3:])
    nome1  = (file1[:len(file1)-4])
    if final1=='txt':
        print(nome1)
        ##my_file = open(r"C:/AI/krypton-01/texto/"+nome1+".txt","r+")
        my_file = open("C:/AI/krypton-01/texto/"+nome1+".txt", 'r').read()
        ##print(my_file)
        print(len(my_file))
        ### Identificacao se é nota e o numero 
        palavra1=""
        for i in range(len(my_file)):
            letra=my_file[i]
            palavra1=palavra1+letra
            if len(palavra1)>32:
                palavra1=palavra1[1:]
            if palavra1 == "NOTAFISCALDESERVIÇOSELETRÔNICANº":
                print("achei uma nota")
                print(palavra1)
                i1=i+1
                #print(i1)
                #print(my_file[i1:i1+1])
                palavra2=""
                while True:
                    #print(my_file[i1:i1+1])
                    if my_file[i1:i1+1]=="0" or my_file[i1:i1+1]=="1" or my_file[i1:i1+1]=="2" or my_file[i1:i1+1]=="3" or my_file[i1:i1+1]=="4" or my_file[i1:i1+1]=="5" or my_file[i1:i1+1]=="6" or my_file[i1:i1+1]=="7" or my_file[i1:i1+1]=="8" or my_file[i1:i1+1]=="9":
                        palavra2=palavra2+my_file[i1:i1+1]
                    else:
                        break
                    i1=i1+1
                print(palavra2)
        #################################
        ## Identificação CNPJ
        palavra12=""
        for i2 in range(len(my_file)):
            letra=my_file[i2]
            palavra12=palavra12+letra
            if len(palavra12)>25:
                palavra12=palavra12[1:]
                if palavra12 == "TomadordosServiçosCPFCNPJ":
                    print("achei um CNPJ")
                    print(palavra12)
                    i2=i2+1
                    #print(i1)
                    #print(my_file[i1:i1+1])
                    palavra3=""
                    while True:
                        ##print(my_file[i2:i2+1])
                        if my_file[i2:i2+1]=="0" or my_file[i2:i2+1]=="1" or my_file[i2:i2+1]=="2" or my_file[i2:i2+1]=="3" or my_file[i2:i2+1]=="4" or my_file[i2:i2+1]=="5" or my_file[i2:i2+1]=="6" or my_file[i2:i2+1]=="7" or my_file[i2:i2+1]=="8" or my_file[i2:i2+1]=="9":
                            palavra3=palavra3+my_file[i2:i2+1]
                        else:
                            break
                        i2=i2+1
                    print(palavra3)
        ## Fim Identificação CNPJ
        #Identificacao valor liquido
        palavra13=""
        for i3 in range(len(my_file)):
            letra=my_file[i3]
            palavra13=palavra13+letra
            if len(palavra13)>17:
                palavra13=palavra13[1:]
                if palavra13 == "ValordosserviçosR":
                    print("achei um valor liquido")
                    print(palavra13)
                    i3=i3+1
                    #print(i1)
                    #print(my_file[i1:i1+1])
                    palavra4=""
                    while True:
                        ##print(my_file[i2:i2+1])
                        if my_file[i3:i3+1]=="0" or my_file[i3:i3+1]=="1" or my_file[i3:i3+1]=="2" or my_file[i3:i3+1]=="3" or my_file[i3:i3+1]=="4" or my_file[i3:i3+1]=="5" or my_file[i3:i3+1]=="6" or my_file[i3:i3+1]=="7" or my_file[i3:i3+1]=="8" or my_file[i3:i3+1]=="9":
                            palavra4=palavra4+my_file[i3:i3+1]
                        else:
                            break
                        i3=i3+1
                    print(palavra4)
# Out:
# 2018-01-03_16-26_3687490
# 1482
# achei uma nota
# NOTAFISCALDESERVIÇOSELETRÔNICANº
# 20177253
# achei um CNPJ
# TomadordosServiçosCPFCNPJ
# 12125171000126
# achei um valor liquido
# ValordosserviçosR
# 000
# 2018-01-03_16-26_4703491
# 1483
# achei uma nota
# NOTAFISCALDESERVIÇOSELETRÔNICANº
# 201764
# achei um CNPJ
# TomadordosServiçosCPFCNPJ
# 12125171000126
# achei um valor liquido
# ValordosserviçosR
# 1001657
# achei um valor liquido
# ValordosserviçosR
# 1001657
# 2018-01-03_16-26_5524444
# 1578
# achei uma nota
# NOTAFISCALDESERVIÇOSELETRÔNICANº
# 201774
# achei um CNPJ
# TomadordosServiçosCPFCNPJ
# 12125171000126
# achei um valor liquido
# ValordosserviçosR
# 000
# 2018-01-03_16-26_6231938
# 1796
# achei uma nota
# NOTAFISCALDESERVIÇOSELETRÔNICANº
# 20171200
# achei um CNPJ
# TomadordosServiçosCPFCNPJ
# 12125171000126
# achei um valor liquido
# ValordosserviçosR
# 797030
# 2018-01-03_16-27_5976388
# 1410
# achei uma nota
# NOTAFISCALDESERVIÇOSELETRÔNICANº
# 20178705
# ...

# %%
print(my_file)

# %%
import pdfminer
pdfminer.__version__
# Out:
# '20191125'
