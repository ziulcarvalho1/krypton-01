# %%
# !pip install tesseract-ocr
# !pip install pytesseract
# !pip install pdf2image
# !pip install imutils
# !pip install pillow

# %%
# !tesseract -v

# %%
# !pip install -y poppler-utils

# %%
# !sudo apt-get install tesseract-ocr-[por]
# Out:
# 'sudo' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image
from pdf2image import convert_from_path
import cv2
import imutils

# %%
from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
image_path_in_colab='C:/AI/Krypton-01/jpegy/2017-06-27_08-47_2081291.jpeg'
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab), lang="por")
print(extractedInformation)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254     try:
# --> 255         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256     except OSError as e:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
mypath="C:\AI\Krypton-01\jpegy-01"
file_names = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

# %%
import datetime
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'
count=0
for i in range(len(file_names)):
  file=file_names[i]
  final = (file[len(file)-4:])
  if final=='jpeg':
        
       
    count=count+1
    print(count,file)
    file_name = (file[:len(file)-5])
    #print(file_name)
    txt = f'C:/AI/Krypton-01/texto-01/'+file_name+'.txt'
    txt2 = f'C:/AI/Krypton-01/jpegy-01/'+file_name+'.jpeg'
    txt1 = f'C:/AI/Krypton-01/'+file_name
    #pages = convert_from_path(f'C:\AI\Krypton-01\jpegy\{file}', 500, poppler_path=r'C:\Program Files\poppler-0.68.0\bin')
    count1=0
    #print(len(pages))
    #print(page)
    #page.show()
    #print(txt)
    #page.save(txt2, 'JPEG')
    print(txt2)
    #if len(pages)!=1:
    #    txt=txt1+'-'+str(count1)+'.txt'
    #print(count,txt)
    count1=count1+1
    now = datetime.datetime.now()
    print(count,txt,now)
    text =pytesseract.image_to_string(Image.open(txt2), lang="por")
    #print(text)
    with open(txt, 'w',encoding='utf-8') as text_file: 
        text_file.write(text)
# Out:
# 1 2018-01-26_14-59_1231485.jpeg
# C:/AI/Krypton-01/jpegy-01/2018-01-26_14-59_1231485.jpeg
# 1 C:/AI/Krypton-01/texto-01/2018-01-26_14-59_1231485.txt 2021-02-26 18:03:34.717156
# 2 2018-01-26_14-59_1448667.jpeg
# C:/AI/Krypton-01/jpegy-01/2018-01-26_14-59_1448667.jpeg
# 2 C:/AI/Krypton-01/texto-01/2018-01-26_14-59_1448667.txt 2021-02-26 18:03:39.676455
# 3 2018-01-26_14-59_1697049.jpeg
# C:/AI/Krypton-01/jpegy-01/2018-01-26_14-59_1697049.jpeg
# 3 C:/AI/Krypton-01/texto-01/2018-01-26_14-59_1697049.txt 2021-02-26 18:03:44.216467
# 4 2019-10-14_09-30-58-1571056258_E_1488_6110909.jpeg
# C:/AI/Krypton-01/jpegy-01/2019-10-14_09-30-58-1571056258_E_1488_6110909.jpeg
# 4 C:/AI/Krypton-01/texto-01/2019-10-14_09-30-58-1571056258_E_1488_6110909.txt 2021-02-26 18:03:49.155460
# 5 2019-10-18_17-38_CP_I_986__8603450.jpeg
# C:/AI/Krypton-01/jpegy-01/2019-10-18_17-38_CP_I_986__8603450.jpeg
# 5 C:/AI/Krypton-01/texto-01/2019-10-18_17-38_CP_I_986__8603450.txt 2021-02-26 18:03:53.474301
# ...
